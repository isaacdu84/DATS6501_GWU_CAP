# %%
import wget
import os

# %%
#create a directory to store the raw inputs and navigate to this directory
if not os.path.exists(os.getcwd() + '/rawInput'):
    os.makedirs(os.getcwd() + '/rawInput')
os.chdir('./rawInput')

# %%
#list the urls to the raw input files in the AWS S3
url1 = 'https://s3.amazonaws.com/gwu.dats6501.rawdata/311_Service_Requests_Tree_Debris.csv'
url2 = 'https://s3.amazonaws.com/gwu.dats6501.rawdata/311_Service_Requests_Pot_Holes_Reported.csv'
url3 = 'https://s3.amazonaws.com/gwu.dats6501.rawdata/311_Service_Requests_Street_Lights_All_Out.csv'
url4 = 'https://s3.amazonaws.com/gwu.dats6501.rawdata/311_Service_Requests_Street_Lights_One_Out.csv'
url5 = 'https://s3.amazonaws.com/gwu.dats6501.rawdata/311_Service_Requests_Tree_Trims.csv'
url6 = 'https://s3.amazonaws.com/gwu.dats6501.rawdata/CRASH2015.csv'
url7 = 'https://s3.amazonaws.com/gwu.dats6501.rawdata/CRASH2016.csv'
url8 = 'https://s3.amazonaws.com/gwu.dats6501.rawdata/ChicagoHwy2015/ChicagoHwy.shp'
url9 = 'https://s3.amazonaws.com/gwu.dats6501.rawdata/ChicagoHwy2015/ChicagoHwy.dbf'
url10 = 'https://s3.amazonaws.com/gwu.dats6501.rawdata/ChicagoHwy2016/ChicagoHwy.dbf'
url11 = 'https://s3.amazonaws.com/gwu.dats6501.rawdata/ChicagoHwy2016/ChicagoHwy.shp'

urls = [url1, url2, url3, url4, url5, url6, url7, url8, url9, url10, url11]

# %%
for i in range(7):
    wget.download(urls[i])
# Out:
#   2% [..                                                                      ]  1040384 / 36070203
#   7% [.....                                                                   ]  2695168 / 36070203
#  11% [........                                                                ]  4202496 / 36070203
# 100% [........................................................................] 53354992 / 53354992

# %%
#create a directory to store the road network information files and navigate to this directory
if not os.path.exists(os.getcwd() + '/ChicagoHwy2015'):
    os.makedirs(os.getcwd() + '/ChicagoHwy2015')
os.chdir('./ChicagoHwy2015')
for i in range(7, 9):
    wget.download(urls[i])

os.chdir('..')#back to the higher directory
if not os.path.exists(os.getcwd() + '/ChicagoHwy2016'):
    os.makedirs(os.getcwd() + '/ChicagoHwy2016')    
os.chdir('./ChicagoHwy2016')
for i in range(9, 11):
    wget.download(urls[i])
# Out:
# 100% [..........................................................................] 2847192 / 2847192
